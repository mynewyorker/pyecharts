# %%
pip install pyecharts
# Out:
# Collecting pyecharts
#   Downloading https://files.pythonhosted.org/packages/33/d7/2eb55a92609c18d4ab6f4425b448bca6f7d08d1c70f328a71c99f0646b75/pyecharts-1.2.0-py3-none-any.whl (143kB)
#      |████████████████████████████████| 153kB 4.9MB/s
# Requirement already satisfied: prettytable in /usr/local/lib/python3.6/dist-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from pyecharts) (2.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->pyecharts) (1.1.1)
# Installing collected packages: pyecharts
# Successfully installed pyecharts-1.2.0

# %%
from pyecharts.charts import Bar

bar = Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])

# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="a8168cdbffb44196ac513e96dd938cbc" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_a8168cdbffb44196ac513e96dd938cbc = echarts.init(
#             document.getElementById('a8168cdbffb44196ac513e96dd938cbc'), 'white', {renderer: 'canvas'});
#         var option_a8168cdbffb44196ac513e96dd938cbc = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_a8168cdbffb44196ac513e96dd938cbc.setOption(option_a8168cdbffb44196ac513e96dd938cbc);
#     });
# </script>

# %%
from pyecharts.charts import Bar

bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="bbb971234fc94112b35af07654dd14b5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_bbb971234fc94112b35af07654dd14b5 = echarts.init(
#             document.getElementById('bbb971234fc94112b35af07654dd14b5'), 'white', {renderer: 'canvas'});
#         var option_bbb971234fc94112b35af07654dd14b5 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_bbb971234fc94112b35af07654dd14b5.setOption(option_bbb971234fc94112b35af07654dd14b5);
#     });
# </script>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
    # 或者直接使用字典参数
    # .set_global_opts(title_opts={"text": "主标题", "subtext": "副标题"})
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="47645e5249ee4d04bdf1ec7aa81d58ee" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_47645e5249ee4d04bdf1ec7aa81d58ee = echarts.init(
#             document.getElementById('47645e5249ee4d04bdf1ec7aa81d58ee'), 'white', {renderer: 'canvas'});
#         var option_47645e5249ee4d04bdf1ec7aa81d58ee = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_47645e5249ee4d04bdf1ec7aa81d58ee.setOption(option_47645e5249ee4d04bdf1ec7aa81d58ee);
#     });
# </script>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8ee7f19d2d25494db9150937be959fdf" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8ee7f19d2d25494db9150937be959fdf = echarts.init(
#             document.getElementById('8ee7f19d2d25494db9150937be959fdf'), 'light', {renderer: 'canvas'});
#         var option_8ee7f19d2d25494db9150937be959fdf = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 15,
#                 6,
#                 45,
#                 20,
#                 35,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_8ee7f19d2d25494db9150937be959fdf.setOption(option_8ee7f19d2d25494db9150937be959fdf);
#     });
# </script>

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar

begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)
    ]

c = (Calendar()
    .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
        visualmap_opts=opts.VisualMapOpts(
        max_=20000,
        min_=500,
        orient="horizontal",
        is_piecewise=True,
        pos_top="230px",
        pos_left="100px",
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4783987765ce4889a8de325a38abeddd" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4783987765ce4889a8de325a38abeddd = echarts.init(
#             document.getElementById('4783987765ce4889a8de325a38abeddd'), 'white', {renderer: 'canvas'});
#         var option_4783987765ce4889a8de325a38abeddd = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     13564
#                 ],
#                 [
#                     "2017-01-02",
#                     16272
#                 ],
#                 [
#                     "2017-01-03",
#                     19131
#                 ],
#                 [
#                     "2017-01-04",
#                     7618
#                 ],
#                 [
#                     "2017-01-05",
#                     23297
#                 ],
#                 [
#                     "2017-01-06",
#                     15613
#                 ],
#                 [
#                     "2017-01-07",
#                     20820
#                 ],
#                 [
#                     "2017-01-08",
#                     15549
#                 ],
#                 [
#                     "2017-01-09",
#                     24677
#                 ],
#                 [
#                     "2017-01-10",
#                     1266
#                 ],
#                 [
#                     "2017-01-11",
#                     19857
#                 ],
#                 [
#                     "2017-01-12",
#                     17557
#                 ],
#                 [
#                     "2017-01-13",
#                     5200
#                 ],
#                 [
#                     "2017-01-14",
#                     15053
#                 ],
#                 [
#                     "2017-01-15",
#                     22916
#                 ],
#                 [
#                     "2017-01-16",
#                     7966
#                 ],
#                 [
#                     "2017-01-17",
#                     12540
#                 ],
#                 [
#                     "2017-01-18",
#                     16531
#                 ],
#                 [
#                     "2017-01-19",
#                     15273
#                 ],
#                 [
#                     "2017-01-20",
#                     17493
#                 ],
#                 [
#                     "2017-01-21",
#                     6318
#                 ],
#                 [
#                     "2017-01-22",
#                     11067
#                 ],
#                 [
#                     "2017-01-23",
#                     7808
#                 ],
#                 [
#                     "2017-01-24",
#                     14526
#                 ],
#                 [
#                     "2017-01-25",
#                     14732
#                 ],
#                 [
#                     "2017-01-26",
#                     7030
#                 ],
#                 [
#                     "2017-01-27",
#                     20685
#                 ],
#                 [
#                     "2017-01-28",
#                     10008
#                 ],
#                 [
#                     "2017-01-29",
#                     22954
#                 ],
#                 [
#                     "2017-01-30",
#                     17298
#                 ],
#                 [
#                     "2017-01-31",
#                     12584
#                 ],
#                 [
#                     "2017-02-01",
#                     6434
#                 ],
#                 [
#                     "2017-02-02",
#                     11713
#                 ],
#                 [
#                     "2017-02-03",
#                     14587
#                 ],
#                 [
#                     "2017-02-04",
#                     12902
#                 ],
#                 [
#                     "2017-02-05",
#                     7656
#                 ],
#                 [
#                     "2017-02-06",
#                     19230
#                 ],
#                 [
#                     "2017-02-07",
#                     11203
#                 ],
#                 [
#                     "2017-02-08",
#                     12348
#                 ],
#                 [
#                     "2017-02-09",
#                     17661
#                 ],
#                 [
#                     "2017-02-10",
#                     6818
#                 ],
#                 [
#                     "2017-02-11",
#                     8311
#                 ],
#                 [
#                     "2017-02-12",
#                     22477
#                 ],
#                 [
#                     "2017-02-13",
#                     16663
#                 ],
#                 [
#                     "2017-02-14",
#                     16793
#                 ],
#                 [
#                     "2017-02-15",
#                     17662
#                 ],
#                 [
#                     "2017-02-16",
#                     16447
#                 ],
#                 [
#                     "2017-02-17",
#                     4643
#                 ],
#                 [
#                     "2017-02-18",
#                     17977
#                 ],
#                 [
#                     "2017-02-19",
#                     12657
#                 ],
#                 [
#                     "2017-02-20",
#                     9882
#                 ],
#                 [
#                     "2017-02-21",
#                     3273
#                 ],
#                 [
#                     "2017-02-22",
#                     11423
#                 ],
#                 [
#                     "2017-02-23",
#                     10276
#                 ],
#                 [
#                     "2017-02-24",
#                     23266
#                 ],
#                 [
#                     "2017-02-25",
#                     18893
#                 ],
#                 [
#                     "2017-02-26",
#                     22835
#                 ],
#                 [
#                     "2017-02-27",
#                     4279
#                 ],
#                 [
#                     "2017-02-28",
#                     1047
#                 ],
#                 [
#                     "2017-03-01",
#                     20625
#                 ],
#                 [
#                     "2017-03-02",
#                     20440
#                 ],
#                 [
#                     "2017-03-03",
#                     24936
#                 ],
#                 [
#                     "2017-03-04",
#                     21075
#                 ],
#                 [
#                     "2017-03-05",
#                     23063
#                 ],
#                 [
#                     "2017-03-06",
#                     5834
#                 ],
#                 [
#                     "2017-03-07",
#                     14756
#                 ],
#                 [
#                     "2017-03-08",
#                     4364
#                 ],
#                 [
#                     "2017-03-09",
#                     11707
#                 ],
#                 [
#                     "2017-03-10",
#                     6580
#                 ],
#                 [
#                     "2017-03-11",
#                     15168
#                 ],
#                 [
#                     "2017-03-12",
#                     5874
#                 ],

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page

c = (Gauge()
    .add("", [("完成率", 66.6)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="779847339b634beb949a8a1a2f6677f6" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_779847339b634beb949a8a1a2f6677f6 = echarts.init(
#             document.getElementById('779847339b634beb949a8a1a2f6677f6'), 'white', {renderer: 'canvas'});
#         var option_779847339b634beb949a8a1a2f6677f6 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_779847339b634beb949a8a1a2f6677f6.setOption(option_779847339b634beb949a8a1a2f6677f6);
#     });
# </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

c = (Liquid()
    .add("lq", [0.6, 0.7])
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#     <div id="e087ae6054a5455d8822bbae6ce7cfeb" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-liquidfill'], function(echarts) {
#         var chart_e087ae6054a5455d8822bbae6ce7cfeb = echarts.init(
#             document.getElementById('e087ae6054a5455d8822bbae6ce7cfeb'), 'white', {renderer: 'canvas'});
#         var option_e087ae6054a5455d8822bbae6ce7cfeb = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_e087ae6054a5455d8822bbae6ce7cfeb.setOption(option_e087ae6054a5455d8822bbae6ce7cfeb);
#     });
# </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Parallel


data = [
        [1, 91, 45, 125, 0.82, 34],
        [2, 65, 27, 78, 0.86, 45],
        [3, 83, 60, 84, 1.09, 73],
        [4, 109, 81, 121, 1.28, 68],
        [5, 106, 77, 114, 1.07, 55],
        [6, 109, 81, 121, 1.28, 68],
        [7, 106, 77, 114, 1.07, 55],
        [8, 89, 65, 78, 0.86, 51, 26],
        [9, 53, 33, 47, 0.64, 50, 17],
        [10, 80, 55, 80, 1.01, 75, 24],
        [11, 117, 81, 124, 1.03, 45],
    ]
    
c = (Parallel()
    .add_schema(
        [
            {"dim": 0, "name": "data"},
            {"dim": 1, "name": "AQI"},
            {"dim": 2, "name": "PM2.5"},
            {"dim": 3, "name": "PM10"},
            {"dim": 4, "name": "CO"},
            {"dim": 5, "name": "NO2"},
        ]
    )
    .add("parallel", data)
    .set_global_opts(title_opts=opts.TitleOpts(title="Parallel-基本示例"))
    )
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="957cbb151207457d836b392745f18ffb" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_957cbb151207457d836b392745f18ffb = echarts.init(
#             document.getElementById('957cbb151207457d836b392745f18ffb'), 'white', {renderer: 'canvas'});
#         var option_957cbb151207457d836b392745f18ffb = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45
#                 ]
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data"
#         },
#         {
#             "dim": 1,
#             "name": "AQI"
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5"
#         },
#         {
#             "dim": 3,
#             "name": "PM10"
#         },
#         {
#             "dim": 4,
#             "name": "CO"
#         },
#         {
#             "dim": 5,
#             "name": "NO2"
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_957cbb151207457d836b392745f18ffb.setOption(option_957cbb151207457d836b392745f18ffb);
#     });
# </script>

# %%
from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie

c = (Pie()
    .add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0fdd7afc8f17425889c0a355b7a6634c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0fdd7afc8f17425889c0a355b7a6634c = echarts.init(
#             document.getElementById('0fdd7afc8f17425889c0a355b7a6634c'), 'white', {renderer: 'canvas'});
#         var option_0fdd7afc8f17425889c0a355b7a6634c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 132
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 136
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 45
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_0fdd7afc8f17425889c0a355b7a6634c.setOption(option_0fdd7afc8f17425889c0a355b7a6634c);
#     });
# </script>

# %%
import math
import random

from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Polar


data = [(i, random.randint(1, 100)) for i in range(101)]
c = (Polar()
     .add("", data, type_="scatter", label_opts=opts.LabelOpts(is_show=False))
     .set_global_opts(title_opts=opts.TitleOpts(title="Polar-Scatter0"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="279f84db6b194308a9d39348731e7261" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_279f84db6b194308a9d39348731e7261 = echarts.init(
#             document.getElementById('279f84db6b194308a9d39348731e7261'), 'white', {renderer: 'canvas'});
#         var option_279f84db6b194308a9d39348731e7261 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     84
#                 ],
#                 [
#                     1,
#                     64
#                 ],
#                 [
#                     2,
#                     15
#                 ],
#                 [
#                     3,
#                     44
#                 ],
#                 [
#                     4,
#                     85
#                 ],
#                 [
#                     5,
#                     12
#                 ],
#                 [
#                     6,
#                     98
#                 ],
#                 [
#                     7,
#                     4
#                 ],
#                 [
#                     8,
#                     53
#                 ],
#                 [
#                     9,
#                     41
#                 ],
#                 [
#                     10,
#                     98
#                 ],
#                 [
#                     11,
#                     60
#                 ],
#                 [
#                     12,
#                     76
#                 ],
#                 [
#                     13,
#                     37
#                 ],
#                 [
#                     14,
#                     48
#                 ],
#                 [
#                     15,
#                     59
#                 ],
#                 [
#                     16,
#                     17
#                 ],
#                 [
#                     17,
#                     52
#                 ],
#                 [
#                     18,
#                     21
#                 ],
#                 [
#                     19,
#                     52
#                 ],
#                 [
#                     20,
#                     33
#                 ],
#                 [
#                     21,
#                     59
#                 ],
#                 [
#                     22,
#                     80
#                 ],
#                 [
#                     23,
#                     77
#                 ],
#                 [
#                     24,
#                     37
#                 ],
#                 [
#                     25,
#                     33
#                 ],
#                 [
#                     26,
#                     9
#                 ],
#                 [
#                     27,
#                     39
#                 ],
#                 [
#                     28,
#                     93
#                 ],
#                 [
#                     29,
#                     66
#                 ],
#                 [
#                     30,
#                     31
#                 ],
#                 [
#                     31,
#                     26
#                 ],
#                 [
#                     32,
#                     99
#                 ],
#                 [
#                     33,
#                     39
#                 ],
#                 [
#                     34,
#                     28
#                 ],
#                 [
#                     35,
#                     84
#                 ],
#                 [
#                     36,
#                     80
#                 ],
#                 [
#                     37,
#                     25
#                 ],
#                 [
#                     38,
#                     50
#                 ],
#                 [
#                     39,
#                     62
#                 ],
#                 [
#                     40,
#                     57
#                 ],
#                 [
#                     41,
#                     34
#                 ],
#                 [
#                     42,
#                     22
#                 ],
#                 [
#                     43,
#                     42
#                 ],
#                 [
#                     44,
#                     54
#                 ],
#                 [
#                     45,
#                     71
#                 ],
#                 [
#                     46,
#                     5
#                 ],
#                 [
#                     47,
#                     46
#                 ],
#                 [
#                     48,
#                     99
#                 ],
#                 [
#                     49,
#                     37
#                 ],
#                 [
#                     50,
#                     53
#                 ],
#                 [
#                     51,
#                     47
#                 ],
#                 [
#                     52,
#                     58
#                 ],
#                 [
#                     53,
#                     24
#                 ],
#                 [
#                     54,
#                     82
#                 ],
#                 [
#                     55,
#                     85
#                 ],
#                 [
#                     56,
#                     71
#                 ],
#                 [
#                     57,
#                     53
#                 ],
#                 [
#                     58,
#                     49
#                 ],
#                 [
#                     59,
#                     67
#                 ],
#                 [
#                     60,
#                     14
#                 ],
#                 [
#                     61,
#                     58
#                 ],
#                 [
#                     62,
#                     7
#                 ],
#                 [
#                     63,
#                     33
#                 ],
#                 [
#                     64,
#                     41
#                 ],
#                 [
#                     65,
#                     56
#                 ],
#                 [
#                     66,
#                     71
#                 ],
#                 [
#                     67,
#                     2
#                 ],
#                 [
#                     68,
#                     78
#                 ],
#                 [
#                     69,
#                     6
#                 ],
#                 [
#                     70,
#                     38
#                 ],
#                 [
#                     71,
#                     99
#                 ],
#                 [
#                     72,
#                     20
#                 ],
#                 [
#                     73,
#                     18
#                 ],
#                 [
#                     74,
#                     57
#                 ],
#                 [
#                     75,
#                     3
#                 ],
#                 [
#                     76,
#                     85
#                 ],
#                 [
#                     77,
#                     2
#                 ],
#                 [
#                     78,
#                     5
#                 ],
#                 [
#                     79,
#                     75
#                 ],
#                 [
#                     80,
#                     70
#                 ],
#                 [
#                     81,
#                     11

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Radar


v1 = [[4300, 10000, 28000, 35000, 50000, 19000]]
v2 = [[5000, 14000, 28000, 31000, 42000, 21000]]

c = (Radar()
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name="销售", max_=6500),
            opts.RadarIndicatorItem(name="管理", max_=16000),
            opts.RadarIndicatorItem(name="信息", max_=30000),
            opts.RadarIndicatorItem(name="客服", max_=38000),
            opts.RadarIndicatorItem(name="研发", max_=52000),
            opts.RadarIndicatorItem(name="市场", max_=25000),
        ]
    )
    .add("预算分配", v1)
    .add("实际开销", v2)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Radar-基本示例"))
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="70be585e6c834e0ab95b637b6d77012e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_70be585e6c834e0ab95b637b6d77012e = echarts.init(
#             document.getElementById('70be585e6c834e0ab95b637b6d77012e'), 'white', {renderer: 'canvas'});
#         var option_70be585e6c834e0ab95b637b6d77012e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d",
#             "data": [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500",
#             "data": [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d",
#                 "\u5b9e\u9645\u5f00\u9500"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d": true,
#                 "\u5b9e\u9645\u5f00\u9500": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u9500\u552e",
#                 "max": 6500
#             },
#             {
#                 "name": "\u7ba1\u7406",
#                 "max": 16000
#             },
#             {
#                 "name": "\u4fe1\u606f\u6280\u672f",
#                 "max": 30000
#             },
#             {
#                 "name": "\u5ba2\u670d",
#                 "max": 38000
#             },
#             {
#                 "name": "\u7814\u53d1",
#                 "max": 52000
#             },
#             {
#                 "name": "\u5e02\u573a",
#                 "max": 25000
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "Radar-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_70be585e6c834e0ab95b637b6d77012e.setOption(option_70be585e6c834e0ab95b637b6d77012e);
#     });
# </script>

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, Sankey


nodes = [
    {"name": "category1"},
    {"name": "category2"},
    {"name": "category3"},
    {"name": "category4"},
    {"name": "category5"},
    {"name": "category6"},
]

links = [
    {"source": "category1", "target": "category2", "value": 10},
    {"source": "category2", "target": "category3", "value": 15},
    {"source": "category3", "target": "category4", "value": 20},
    {"source": "category5", "target": "category6", "value": 25},
]
    
c = (Sankey()
    .add("sankey",
        nodes,
        links,
        linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
        label_opts=opts.LabelOpts(position="right"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Sankey-基本示例"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="864d1d6ab4fd45b6988dd5a266b3dbda" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_864d1d6ab4fd45b6988dd5a266b3dbda = echarts.init(
#             document.getElementById('864d1d6ab4fd45b6988dd5a266b3dbda'), 'white', {renderer: 'canvas'});
#         var option_864d1d6ab4fd45b6988dd5a266b3dbda = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "category1"
#                 },
#                 {
#                     "name": "category2"
#                 },
#                 {
#                     "name": "category3"
#                 },
#                 {
#                     "name": "category4"
#                 },
#                 {
#                     "name": "category5"
#                 },
#                 {
#                     "name": "category6"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "category1",
#                     "target": "category2",
#                     "value": 10
#                 },
#                 {
#                     "source": "category2",
#                     "target": "category3",
#                     "value": 15
#                 },
#                 {
#                     "source": "category3",
#                     "target": "category4",
#                     "value": 20
#                 },
#                 {
#                     "source": "category5",
#                     "target": "category6",
#                     "value": 25
#                 }
#             ],
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sankey-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_864d1d6ab4fd45b6988dd5a266b3dbda.setOption(option_864d1d6ab4fd45b6988dd5a266b3dbda);
#     });
# </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Sunburst


data = [opts.SunburstItem(
        name="Grandpa",
        children=[
            opts.SunburstItem(
            name="Uncle Leo",
            value=15,
            children=[
                    opts.SunburstItem(name="Cousin Jack", value=2),
                    opts.SunburstItem(
                        name="Cousin Mary",
                        value=5,
                        children=[opts.SunburstItem(name="Jackson", value=2)],
                    ),
                    opts.SunburstItem(name="Cousin Ben", value=4),
                ],
            ),
            opts.SunburstItem(
                name="Father",
                value=10,
                children=[
                    opts.SunburstItem(name="Me", value=5),
                    opts.SunburstItem(name="Brother Peter", value=1),
                ],
            ),
        ],
    ),
        opts.SunburstItem(
        name="Nancy",
        children=[
            opts.SunburstItem(
                name="Uncle Nike",
                children=[
                    opts.SunburstItem(name="Cousin Betty", value=1),
                    opts.SunburstItem(name="Cousin Jenny", value=2),
                ],
            )
        ],
    ),
]

c = (Sunburst()
    .add(series_name="", data_pair=data, radius=[0, "90%"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Sunburst-基本示例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="516bbd0b54f2486b8cd8796d4015c784" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_516bbd0b54f2486b8cd8796d4015c784 = echarts.init(
#             document.getElementById('516bbd0b54f2486b8cd8796d4015c784'), 'white', {renderer: 'canvas'});
#         var option_516bbd0b54f2486b8cd8796d4015c784 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "data": [
#                 {
#                     "name": "Grandpa",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "value": 15,
#                             "name": "Uncle Leo",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jack",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 5,
#                                     "name": "Cousin Mary",
#                                     "target": "blank",
#                                     "children": [
#                                         {
#                                             "value": 2,
#                                             "name": "Jackson",
#                                             "target": "blank"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "value": 4,
#                                     "name": "Cousin Ben",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 10,
#                             "name": "Father",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 5,
#                                     "name": "Me",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 1,
#                                     "name": "Brother Peter",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Nancy",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "Uncle Nike",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 1,
#                                     "name": "Cousin Betty",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jenny",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 0,
#                 "90%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "formatter": "{b}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sunburst-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_516bbd0b54f2486b8cd8796d4015c784.setOption(option_516bbd0b54f2486b8cd8796d4015c784);
#     });
# </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, ThemeRiver

data = [
        ["2015/11/08", 10, "DQ"],
        ["2015/11/09", 15, "DQ"],
        ["2015/11/10", 35, "DQ"],
        ["2015/11/14", 7, "DQ"],
        ["2015/11/15", 2, "DQ"],
        ["2015/11/16", 17, "DQ"],
        ["2015/11/17", 33, "DQ"],
        ["2015/11/18", 40, "DQ"],
        ["2015/11/19", 32, "DQ"],
        ["2015/11/20", 26, "DQ"],
        ["2015/11/08", 35, "TY"],
        ["2015/11/09", 36, "TY"],
        ["2015/11/10", 37, "TY"],
        ["2015/11/11", 22, "TY"],
        ["2015/11/12", 24, "TY"],
        ["2015/11/13", 26, "TY"],
        ["2015/11/14", 34, "TY"],
        ["2015/11/15", 21, "TY"],
        ["2015/11/16", 18, "TY"],
        ["2015/11/17", 45, "TY"],
        ["2015/11/18", 32, "TY"],
        ["2015/11/19", 35, "TY"],
        ["2015/11/20", 30, "TY"],
        ["2015/11/08", 21, "SS"],
        ["2015/11/09", 25, "SS"],
        ["2015/11/10", 27, "SS"],
        ["2015/11/11", 23, "SS"],
        ["2015/11/12", 24, "SS"],
        ["2015/11/13", 21, "SS"],
        ["2015/11/14", 35, "SS"],
        ["2015/11/15", 39, "SS"],
        ["2015/11/16", 40, "SS"],
        ["2015/11/17", 36, "SS"],
        ["2015/11/18", 33, "SS"],
        ["2015/11/19", 43, "SS"],
        ["2015/11/20", 40, "SS"],
        ["2015/11/14", 7, "QG"],
        ["2015/11/15", 2, "QG"],
        ["2015/11/16", 17, "QG"],
        ["2015/11/17", 33, "QG"],
        ["2015/11/18", 40, "QG"],
        ["2015/11/19", 32, "QG"],
        ["2015/11/20", 26, "QG"],
        ["2015/11/21", 35, "QG"],
        ["2015/11/22", 40, "QG"],
        ["2015/11/23", 32, "QG"],
        ["2015/11/24", 26, "QG"],
        ["2015/11/25", 22, "QG"],
        ["2015/11/08", 10, "SY"],
        ["2015/11/09", 15, "SY"],
        ["2015/11/10", 35, "SY"],
        ["2015/11/11", 38, "SY"],
        ["2015/11/12", 22, "SY"],
        ["2015/11/13", 16, "SY"],
        ["2015/11/14", 7, "SY"],
        ["2015/11/15", 2, "SY"],
        ["2015/11/16", 17, "SY"],
        ["2015/11/17", 33, "SY"],
        ["2015/11/18", 40, "SY"],
        ["2015/11/19", 32, "SY"],
        ["2015/11/20", 26, "SY"],
        ["2015/11/21", 35, "SY"],
        ["2015/11/22", 4, "SY"],
        ["2015/11/23", 32, "SY"],
        ["2015/11/24", 26, "SY"],
        ["2015/11/25", 22, "SY"],
        ["2015/11/08", 10, "DD"],
        ["2015/11/09", 15, "DD"],
        ["2015/11/10", 35, "DD"],
        ["2015/11/11", 38, "DD"],
        ["2015/11/12", 22, "DD"],
        ["2015/11/13", 16, "DD"],
        ["2015/11/14", 7, "DD"],
        ["2015/11/15", 2, "DD"],
        ["2015/11/16", 17, "DD"],
        ["2015/11/17", 33, "DD"],
        ["2015/11/18", 4, "DD"],
        ["2015/11/19", 32, "DD"],
        ["2015/11/20", 26, "DD"],
]
    
c = (ThemeRiver()
    .add(
        ["DQ", "TY", "SS", "QG", "SY", "DD"],
        data,
        singleaxis_opts=opts.SingleAxisOpts(type_="time", pos_bottom="10%"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="ThemeRiver-基本示例"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="a710d5a3805c4321b4070be7dc2ec1ff" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_a710d5a3805c4321b4070be7dc2ec1ff = echarts.init(
#             document.getElementById('a710d5a3805c4321b4070be7dc2ec1ff'), 'white', {renderer: 'canvas'});
#         var option_a710d5a3805c4321b4070be7dc2ec1ff = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "themeRiver",
#             "name": [
#                 "DQ",
#                 "TY",
#                 "SS",
#                 "QG",
#                 "SY",
#                 "DD"
#             ],
#             "data": [
#                 [
#                     "2015/11/08",
#                     10,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/09",
#                     15,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/10",
#                     35,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/15",
#                     2,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/16",
#                     17,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/17",
#                     33,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/18",
#                     40,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/19",
#                     32,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/20",
#                     26,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/08",
#                     35,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/09",
#                     36,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/10",
#                     37,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/11",
#                     22,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/12",
#                     24,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/13",
#                     26,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/14",
#                     34,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/15",
#                     21,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/16",
#                     18,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/17",
#                     45,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/18",
#                     32,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/19",
#                     35,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/20",
#                     30,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/08",
#                     21,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/09",
#                     25,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/10",
#                     27,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/11",
#                     23,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/12",
#                     24,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/13",
#                     21,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/14",
#                     35,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/15",
#                     39,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/16",
#                     40,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/17",
#                     36,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/18",
#                     33,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/19",
#                     43,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/20",
#                     40,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/15",
#                     2,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/16",
#                     17,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/17",
#                     33,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/18",
#                     40,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/19",
#                     32,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/20",
#                     26,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/21",
#                     35,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/22",
#                     40,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/23",
#                     32,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/24",
#                     26,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/25",
#                     22,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/08",
#                     10,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/09",
#                     15,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/10",
#                     35,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/11",
#                     38,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/12",
#                     22,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/13",
#                     16,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/15",
#                     2,
#                     "SY"
#                 ],
#                 [

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType


words = [
    ("Sam S Club", 10000),
    ("Macys", 6181),
    ("Amy Schumer", 4386),
    ("Jurassic World", 4055),
    ("Charter Communications", 2467),
    ("Chick Fil A", 2244),
    ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484),
    ("Express", 1112),
    ("Home", 865),
    ("Johnny Depp", 847),
    ("Lena Dunham", 582),
    ("Lewis Hamilton", 555),
    ("KXAN", 550),
    ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366),
    ("Rita Ora", 360),
    ("Serena Williams", 282),
    ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]

c = (WordCloud()
    .add("", words, word_size_range=[15, 100])
    .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="7eb60ad3d3924aa0acdc507b4bd5d9ff" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_7eb60ad3d3924aa0acdc507b4bd5d9ff = echarts.init(
#             document.getElementById('7eb60ad3d3924aa0acdc507b4bd5d9ff'), 'white', {renderer: 'canvas'});
#         var option_7eb60ad3d3924aa0acdc507b4bd5d9ff = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 15,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,55,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,34,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,3,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,82,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,61,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,60,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,15,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,2,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,120,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,72,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,99,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,104,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,144,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,14,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,102,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,94,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,153,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,36,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,33,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,84,75)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "WordCloud-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_7eb60ad3d3924aa0acdc507b4bd5d9ff.setOption(option_7eb60ad3d3924aa0acdc507b4bd5d9ff);
#     });
# </script>

# %%
from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Scatter

c = (Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-VisualMap(Size)"),
        visualmap_opts=opts.VisualMapOpts(type_="size", max_=150, min_=20),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="48526bb91ab64c7d85711f6ee934168e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_48526bb91ab64c7d85711f6ee934168e = echarts.init(
#             document.getElementById('48526bb91ab64c7d85711f6ee934168e'), 'white', {renderer: 'canvas'});
#         var option_48526bb91ab64c7d85711f6ee934168e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     49
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     79
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     125
#                 ],
#                 [
#                     "\u5468\u56db",
#                     55
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     84
#                 ],
#                 [
#                     "\u5468\u516d",
#                     105
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     122
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     107
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     127
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     32
#                 ],
#                 [
#                     "\u5468\u56db",
#                     76
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     104
#                 ],
#                 [
#                     "\u5468\u516d",
#                     53
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     26
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-VisualMap(Size)"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_48526bb91ab64c7d85711f6ee934168e.setOption(option_48526bb91ab64c7d85711f6ee934168e);
#     });
# </script>

# %%
from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Geo-基本示例"),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="6cb7a86a0ea44dcbb6e0c7bc6378771e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_6cb7a86a0ea44dcbb6e0c7bc6378771e = echarts.init(
#             document.getElementById('6cb7a86a0ea44dcbb6e0c7bc6378771e'), 'white', {renderer: 'canvas'});
#         var option_6cb7a86a0ea44dcbb6e0c7bc6378771e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         106
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         145
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         95
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         108
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         75
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         144
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         50
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b"
#         }
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_6cb7a86a0ea44dcbb6e0c7bc6378771e.setOption(option_6cb7a86a0ea44dcbb6e0c7bc6378771e);
#     });
# </script>
